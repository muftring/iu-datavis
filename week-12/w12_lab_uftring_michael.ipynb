# %% [markdown]
# # W11 Lab Assignment
#
# Maps

# %% [markdown]
# ## Basemap

# %% [markdown]
# `Basemap` (official documention [here](http://matplotlib.org/basemap/index.html), unofficial documentation [here](http://basemaptutorial.readthedocs.io/en/latest/index.html) ) is a Python package for visualization with maps. To install it, open your terminal and run:
#
# `conda install basemap`

# %% [markdown]
# Windows users may run into some problems with installation. [Here](https://github.com/yy/dviz-course/wiki/Basemap-installation-trouble-shooting) is a troubleshooting document.

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap
# %matplotlib inline

# %% [markdown]
# Now we can draw our first map:

# %%
map = Basemap()
map.drawcoastlines()

# %% [markdown]
# The default projection is the [Equirectangular projection](https://en.wikipedia.org/wiki/Equirectangular_projection). We can change to another projection:

# %%
map = Basemap(projection='ortho', lat_0=0, lon_0=0)
map.drawcoastlines()
# Out:
# /opt/anaconda/lib/python3.5/site-packages/mpl_toolkits/basemap/__init__.py:1623: MatplotlibDeprecationWarning: The get_axis_bgcolor function was deprecated in version 2.0. Use get_facecolor instead.
#   fill_color = ax.get_axis_bgcolor()

# %% [markdown]
# `lat_0` and `lon_0` sets the center of the map. Changing it allows us to see the other parts of the earth.

# %%
map = Basemap(projection='ortho', lat_0=0, lon_0=90)
map.drawcoastlines()
# Out:
# /opt/anaconda/lib/python3.5/site-packages/mpl_toolkits/basemap/__init__.py:1623: MatplotlibDeprecationWarning: The get_axis_bgcolor function was deprecated in version 2.0. Use get_facecolor instead.
#   fill_color = ax.get_axis_bgcolor()

# %% [markdown]
# Fill the continents and oceans with some colors:

# %%
map = Basemap(projection='ortho', lat_0=0, lon_0=0)
map.drawmapboundary(fill_color='aqua')
map.fillcontinents(color='coral',lake_color='aqua')
map.drawcoastlines()
# Out:
# /opt/anaconda/lib/python3.5/site-packages/mpl_toolkits/basemap/__init__.py:1767: MatplotlibDeprecationWarning: The get_axis_bgcolor function was deprecated in version 2.0. Use get_facecolor instead.
#   axisbgc = ax.get_axis_bgcolor()

# %% [markdown]
# Add country lines:

# %%
map = Basemap(projection='ortho', lat_0=0, lon_0=0)
map.drawmapboundary(fill_color='aqua')
map.fillcontinents(color='coral',lake_color='aqua')
map.drawcoastlines()
map.drawcountries()
# Out:
# /opt/anaconda/lib/python3.5/site-packages/mpl_toolkits/basemap/__init__.py:1767: MatplotlibDeprecationWarning: The get_axis_bgcolor function was deprecated in version 2.0. Use get_facecolor instead.
#   axisbgc = ax.get_axis_bgcolor()

# %% [markdown]
# The map is essentially a matplotlib object, so we can use matplotlib's methods to access it, for example, draw some points on the map.

# %%
map = Basemap(projection='ortho', lat_0=0, lon_0=-30)
map.drawmapboundary(fill_color='aqua')
map.fillcontinents(color='coral',lake_color='aqua')
map.drawcoastlines()
x, y = map(-10, 0) #x=longitude, y=latitude
map.plot(x, y, marker='D',color='m')
# Out:
# /opt/anaconda/lib/python3.5/site-packages/mpl_toolkits/basemap/__init__.py:1767: MatplotlibDeprecationWarning: The get_axis_bgcolor function was deprecated in version 2.0. Use get_facecolor instead.
#   axisbgc = ax.get_axis_bgcolor()
# /opt/anaconda/lib/python3.5/site-packages/mpl_toolkits/basemap/__init__.py:3260: MatplotlibDeprecationWarning: The ishold function was deprecated in version 2.0.
#   b = ax.ishold()
# /opt/anaconda/lib/python3.5/site-packages/mpl_toolkits/basemap/__init__.py:3269: MatplotlibDeprecationWarning: axes.hold is deprecated.
#     See the API Changes document (http://matplotlib.org/api/api_changes.html)
#     for more details.
#   ax.hold(b)

# %% [markdown]
# Try with this: put a dot on your favourite city and put its name next to it. You can use the [text](http://basemaptutorial.readthedocs.io/en/latest/plotting_data.html#text) function. (It may be necessary to rotate your map).

# %%
# My Favourite City
city = 'London'
lat = 51.5074
lon = 0.1278

# %%
# draw a point for a city on the map.

map = Basemap(projection='ortho', lat_0=lat, lon_0=lon)
map.drawmapboundary(fill_color='aqua')
map.fillcontinents(color='coral',lake_color='aqua')
map.drawcoastlines()

x, y = map(lon, lat)
map.plot(x, y, marker='D',color='b')

x, y = map(lon+2, lat-2)
plt.text(x, y, city, fontsize=12, fontweight='bold',
                    ha='left', va='center', color='b',
                    bbox=dict(facecolor='b', alpha=0.1))
plt.show()
# Out:
# /opt/anaconda/lib/python3.5/site-packages/mpl_toolkits/basemap/__init__.py:1767: MatplotlibDeprecationWarning: The get_axis_bgcolor function was deprecated in version 2.0. Use get_facecolor instead.
#   axisbgc = ax.get_axis_bgcolor()
# /opt/anaconda/lib/python3.5/site-packages/mpl_toolkits/basemap/__init__.py:3260: MatplotlibDeprecationWarning: The ishold function was deprecated in version 2.0.
#   b = ax.ishold()
# /opt/anaconda/lib/python3.5/site-packages/mpl_toolkits/basemap/__init__.py:3269: MatplotlibDeprecationWarning: axes.hold is deprecated.
#     See the API Changes document (http://matplotlib.org/api/api_changes.html)
#     for more details.
#   ax.hold(b)

# %% [markdown]
# It is also possible to only draw a region within a given "box" by passing the coordinates of the lower-left corner and upper-right corner.

# %%
map = Basemap(llcrnrlon=-10.5,llcrnrlat=35,urcrnrlon=4.,urcrnrlat=44.,
             resolution='i', projection='tmerc', lat_0 = 39.5, lon_0 = -3.25)

map.drawmapboundary(fill_color='aqua')
map.fillcontinents(color='coral',lake_color='aqua')
map.drawcoastlines()
# Out:
# /opt/anaconda/lib/python3.5/site-packages/mpl_toolkits/basemap/__init__.py:1767: MatplotlibDeprecationWarning: The get_axis_bgcolor function was deprecated in version 2.0. Use get_facecolor instead.
#   axisbgc = ax.get_axis_bgcolor()

# %%
# plot the region with the city that you just plotted at the center.

map = Basemap(llcrnrlon=lon-10.0,llcrnrlat=lat-5.0,urcrnrlon=lon+10.0,urcrnrlat=lat+5.0,
             resolution='i', projection='tmerc', lat_0 = lat, lon_0 = lon)

map.drawmapboundary(fill_color='aqua')
map.fillcontinents(color='coral',lake_color='aqua')
map.drawcoastlines()

x, y = map(lon, lat)
map.plot(x, y, marker='D',color='b')

x, y = map(lon+0.5, lat-0.5)
plt.text(x, y, city, fontsize=12, fontweight='bold',
                    ha='left', va='center', color='b',
                    bbox=dict(facecolor='b', alpha=0.1))
plt.show()
# Out:
# /opt/anaconda/lib/python3.5/site-packages/mpl_toolkits/basemap/__init__.py:1767: MatplotlibDeprecationWarning: The get_axis_bgcolor function was deprecated in version 2.0. Use get_facecolor instead.
#   axisbgc = ax.get_axis_bgcolor()
# /opt/anaconda/lib/python3.5/site-packages/mpl_toolkits/basemap/__init__.py:3260: MatplotlibDeprecationWarning: The ishold function was deprecated in version 2.0.
#   b = ax.ishold()
# /opt/anaconda/lib/python3.5/site-packages/mpl_toolkits/basemap/__init__.py:3269: MatplotlibDeprecationWarning: axes.hold is deprecated.
#     See the API Changes document (http://matplotlib.org/api/api_changes.html)
#     for more details.
#   ax.hold(b)
