# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# This looks interesting:
# http://www.sengpielaudio.com/calculator-notenames.htm

# %%
xvals = [ 1, 10, 100, 1000, 10000, 100000, 1000000]
yvals = [ 0, 0, 0, 0, 0, 0, 0]

plt.plot(xvals, yvals)
plt.scatter(1000,0)
plt.xscale('log')

# %%
xvals = [ 1, 2, 10]
yvals = [ 0, 0, 0]

plt.plot(xvals, yvals)
plt.scatter(5, 0)
plt.xscale('log')

# %% [markdown]
# week-11 recap quiz work

# %%
xvals = [ 1, 10, 100, 1000, 10000, 100000, 1000000, 10000000]
yvals = [ 0, 0, 0, 0, 0, 0, 0, 0]

plt.plot(xvals, yvals)
plt.scatter(5,0)
plt.scatter(10,0)
plt.scatter(500000,0)
plt.scatter(1000000,0)
plt.xscale('log')

# %% [markdown]
# logarithmic bins
