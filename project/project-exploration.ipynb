# %%
import pandas as pd

# %%
df = pd.read_csv('us-cities-wikipedia.csv', delimiter=',')

# %%
df.head(25)
# Out:
#     2016 rank               City              State[5] 2016 estimate  \
# 0           1        New York[6]              New York     8,537,673
# 1           2        Los Angeles            California     3,976,322
# 2           3            Chicago              Illinois     2,704,958
# 3           4         Houston[7]                 Texas     2,303,482
# 4           5            Phoenix               Arizona     1,615,017
# 5           6    Philadelphia[8]          Pennsylvania     1,567,872
# 6           7        San Antonio                 Texas     1,492,510
# 7           8          San Diego            California     1,406,630
# 8           9             Dallas                 Texas     1,317,929
# 9          10           San Jose            California     1,025,350
# 10         11             Austin                 Texas       947,890
# 11         12    Jacksonville[9]               Florida       880,619
# 12         13  San Francisco[10]            California       870,887
# ...
